# %% [markdown]
# # json file and folder creation

# %%
import os
from keras.models import load_model
from PIL import Image, ImageOps
import numpy as np
import os
import cv2
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances
import matplotlib.pyplot as plt

import sys
import os
import json
import shutil
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# C:\Users\admin\AppData\Roaming\Python\Python39\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
# Set the directories containing the folders
source_directories = [
    r"data"
]

# Check if the destination folder already exists, create it if not
destination_directory = r"des"

# %%
os.makedirs(destination_directory, exist_ok=True)

# Iterate over the source directories
for source_directory in source_directories:
    # Iterate over the folders in the source directory
    for folder_name in os.listdir(source_directory):
        folder_path = os.path.join(source_directory, folder_name)

        # Check if the item in the directory is a folder
        if os.path.isdir(folder_path):
            # Find the JSON file within the folder
            json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]

            # Check if there is exactly one JSON file in the folder
            if len(json_files) == 1:
                json_file_name = json_files[0]
                json_file_path = os.path.join(folder_path, json_file_name)

                # Load and process the JSON file
                with open(json_file_path, encoding = "utf8",errors = "ignore") as json_file:
                    try:
                        json_data = json.load(json_file)
                    except json.JSONDecodeError as e:
                        print(f"Error loading JSON file '{json_file_path}': {str(e)}")
                        continue

                # Access the desired data from the JSON
                product_category = json_data.get("productType")

                # Create folder and name it according to the product category
                if product_category:
                    folder_name_new = product_category.lower().replace(" ", "_")
                else:
                    folder_name_new = "folder_without_category"

                # Create the new folder in the destination directory
                new_folder_path = os.path.join(destination_directory, folder_name_new)
                os.makedirs(new_folder_path, exist_ok=True)

                # copy the contents of the original folder to the new folder
                for file_name in os.listdir(folder_path):
                    file_path = os.path.join(folder_path, file_name)
                    new_file_path = os.path.join(new_folder_path, file_name)

                    # Check if a file with the same name already exists in the destination folder
                    if os.path.exists(new_file_path):
                        file_name_base, file_extension = os.path.splitext(file_name)
                        renamed_file_name = f"{file_name_base}_1{file_extension}"
                        renamed_file_path = os.path.join(new_folder_path, renamed_file_name)

                        # Rename the file with a postfix if it already exists
                        shutil.copy(file_path, renamed_file_path)
                    else:
                        shutil.copy(file_path, new_folder_path)

                print(f"Folder '{folder_name}' from '{source_directory}' processed and copied to '{new_folder_path}'.")
            else:
                print(f"Skipping folder '{folder_name}' in '{source_directory}' as it does not contain a single JSON file.")
# Out:
# Folder 'PTRC01ZFMZRYJYBJ' from 'data' processed and copied to 'des\barbecue_grill'.
# Folder 'PTRC02BAT4J41NZN' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC03QFH6E0TRXR' from 'data' processed and copied to 'des\scanner'.
# Folder 'PTRC05FFXT6DKUM2' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC05FWD4GZXGP3' from 'data' processed and copied to 'des\toilet'.
# Folder 'PTRC077XB2L7YXPA' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC09ZVA0KN3GJK' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC09ZZEFG2NPEJ' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC0A0V718FX554' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC0A0ZTWCNJE65' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC0BC7YL1GYZ09' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC0CR2C1NDQ2QF' from 'data' processed and copied to 'des\food_blender'.
# Folder 'PTRC0D4BRYH1KKQK' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC0FWEB3URR79V' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC0G8V09HGA3KZ' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC0KCUXDL31L7D' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC0M43P3FH0VUM' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC0M485U26BKVM' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRC0Q8X6U5HTG52' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC0TZ4DVE12JRD' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC0UCN9JP200WG' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC0W3TEVHCHG2U' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC0XGGRAD3TM7X' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC10CYJG3NZCZB' from 'data' processed and copied to 'des\speakers'.
# Folder 'PTRC13GQ5AA71J9T' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC14V07ANMJCVW' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC14V93EMXVZ5W' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC16L9E1HR5VV6' from 'data' processed and copied to 'des\laundry_appliance'.
# Folder 'PTRC1ARVZ24DVB75' from 'data' processed and copied to 'des\rice_cookers'.
# Folder 'PTRC1B5YGYUG4F08' from 'data' processed and copied to 'des\storage_box'.
# Folder 'PTRC1CH30Y1UCPTF' from 'data' processed and copied to 'des\personal_computer'.
# Folder 'PTRC1CHNC6ZNBN1D' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRC1E9DPJDR1CEN' from 'data' processed and copied to 'des\laundry_hamper'.
# Folder 'PTRC1G00CHRP9AC1' from 'data' processed and copied to 'des\toilet'.
# Folder 'PTRC1HDR2LJUQTC5' from 'data' processed and copied to 'des\humidifier'.
# Folder 'PTRC1JRR8GYZXZL7' from 'data' processed and copied to 'des\sofa'.
# Folder 'PTRC1LH159AX5R7F' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRC1MW0C1N5QMPP' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC1PMRPD37EC3Y' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC1Q001YPRX2B3' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC1RCRDYAVK479' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC1RCUA70EPCZ8' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC1TRTJ52HPY5B' from 'data' processed and copied to 'des\air_purifier'.
# Folder 'PTRC1VG8LX36WUCP' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC1VGF0XDGCT4M' from 'data' processed and copied to 'des\sofa'.
# Folder 'PTRC1YL673NL9MK3' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC22WXQBEW3AFJ' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRC250BHEQECVZ1' from 'data' processed and copied to 'des\trash_can'.
# Folder 'PTRC27RUT7DM2KB9' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC284UKYR6Z6DE' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC29G32Y4A58CK' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC29G7BWRAEUZJ' from 'data' processed and copied to 'des\chair'.
# Folder 'PTRC29GB35L3QEPL' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC2AJ3XZYJGRZ4' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC2CAD1KA6TP0D' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC2GT7N7CCTHKX' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC2PD6GC2XN51Y' from 'data' processed and copied to 'des\aroma_diffuser'.
# Folder 'PTRC2PDZUE9EVGWY' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC2TH7TG90ZT8D' from 'data' processed and copied to 'des\outbuilding'.
# Folder 'PTRC2THB3DX08BVD' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRC2THBTGEUWMEC' from 'data' processed and copied to 'des\sofa'.
# Folder 'PTRC2V9GFQDV8N5L' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC2V9R1XWX6K2K' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC2WMXDGCNRF5R' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC2X0L9PHVZM6X' from 'data' processed and copied to 'des\air_conditioner'.
# Folder 'PTRC2X0P7BFJGPMW' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC319C9NP085WE' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC33122YE337PM' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC34DCX8GH1TUU' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC3AA7YXFGPGL5' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC3AAR9R678M43' from 'data' processed and copied to 'des\shelf'.
# Folder 'PTRC3AAXQHTXLC53' from 'data' processed and copied to 'des\utility_cart_wagon'.
# Folder 'PTRC3BPG7K9BACL4' from 'data' processed and copied to 'des\electric_water_boiler'.
# Folder 'PTRC3BPXVCBHBDC6' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC3DED4YAWLE0H' from 'data' processed and copied to 'des\saute_fry_pan'.
# Folder 'PTRC3EUQB40H40NL' from 'data' processed and copied to 'des\storage_rack'.
# Folder 'PTRC3F649VZBMTNR' from 'data' processed and copied to 'des\saute_fry_pan'.
# Folder 'PTRC3GJ7Q5QG3D1Z' from 'data' processed and copied to 'des\stringed_instruments'.
# Folder 'PTRC3HYCBRWR5481' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC3ME3VX2JJRYK' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC3MEZQF65YJ2L' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC3P68CPA07EZU' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC3RXAFWF0HHZ6' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC3RXFXL2NW7Z6' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC3WEJ7GAWLBEP' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC3Y5EH1C06ZZ0' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC3ZJU2FTYF3T4' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC40N53N73C1J8' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC40N7FB5GJBE9' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC4128XFDD1VRC' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC412WGWH1FT5A' from 'data' processed and copied to 'des\table'.
# Folder 'PTRC46XKD8TN4L13' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC47A0N4YHEU55' from 'data' processed and copied to 'des\cellular_phone'.
# Folder 'PTRC47AQ8C7158Y7' from 'data' processed and copied to 'des\ice_maker'.
# Folder 'PTRC4A3XDNV6NPXZ' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRC4HPZAX61RQJ0' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC4J267XJWK2X7' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRC4KFWDYN06VCA' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC4NK812B6VAHN' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC4PYJXQMP6NBV' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC4T2HJAF7YA97' from 'data' processed and copied to 'des\camera_digital'.
# Folder 'PTRC4UE80CKTXX4F' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRC4UEC5UF6G40E' from 'data' processed and copied to 'des\workbench'.
# Folder 'PTRC4VUMA9PM738H' from 'data' processed and copied to 'des\chair'.
# Folder 'PTRC4W6XN6J92L8M' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC4XJFHP4FLCNW' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC4XJVCU8HUU5U' from 'data' processed and copied to 'des\cellular_phone'.
# Folder 'PTRC4ZADWT4H0HN2' from 'data' processed and copied to 'des\portable_tool_box'.
# Folder 'PTRC50FJ2YD5A374' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC53KMEU2EEBWK' from 'data' processed and copied to 'des\cooking_pot'.
# Folder 'PTRC54YZR7TV6JJU' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRC56P71T0994K0' from 'data' processed and copied to 'des\table'.
# Folder 'PTRC58ETVVWQUMHD' from 'data' processed and copied to 'des\stringed_instruments'.
# Folder 'PTRC59U6Z99ZEGYE' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC5AV6WBZT84J0' from 'data' processed and copied to 'des\clothes_rack'.
# Folder 'PTRC5CL6CDL87CZA' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC5G3CGLJTR94V' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC5K73PTUXN5KA' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC5K7CA0A0L2G9' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC5K7Y8177AFKA' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC5LKJPX0UKQAF' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC5MZTH2J0H7DH' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC5NBPBTRRJZAQ' from 'data' processed and copied to 'des\food_mixer'.
# Folder 'PTRC5Q3RFJVPNJRY' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC5RFHHLZKZW73' from 'data' processed and copied to 'des\rice_cookers'.
# Folder 'PTRC5U7WDDHA4H0A' from 'data' processed and copied to 'des\electric_water_boiler'.
# Folder 'PTRC5WYGYW4MN47M' from 'data' processed and copied to 'des\laundry_hamper'.
# Folder 'PTRC5WYLC9G8L1HN' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC61K109MTMT4A' from 'data' processed and copied to 'des\cellular_phone'.
# Folder 'PTRC63B3DL0UQ98K' from 'data' processed and copied to 'des\storage_hook'.
# Folder 'PTRC64P7F8ZCYEYQ' from 'data' processed and copied to 'des\chair'.
# Folder 'PTRC687FK5HJTRH9' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC69KR8ZVC1ZXE' from 'data' processed and copied to 'des\home'.
# Folder 'PTRC6B07Y1B1ZG83' from 'data' processed and copied to 'des\toaster'.
# Folder 'PTRC6DQDPA6LUP0C' from 'data' processed and copied to 'des\storage_box'.
# Folder 'PTRC6E408Y2BPZ4H' from 'data' processed and copied to 'des\basket'.
# Folder 'PTRC6GVNV64W15TV' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC6JL26BXD8VP4' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC6JL5QUTGGB05' from 'data' processed and copied to 'des\aroma_diffuser'.
# Folder 'PTRC6JLA7JD6U105' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC6LC00U48N3UC' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC6LC3YF2Y649A' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC6MQYQU1LU3FJ' from 'data' processed and copied to 'des\thermos'.
# Folder 'PTRC6N3Q02BALD3P' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC6PG9JW4454TR' from 'data' processed and copied to 'des\thermos'.
# Folder 'PTRC6QV6DZJ0KPEZ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC6R744YFCQP24' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC6R79KP212D34' from 'data' processed and copied to 'des\outbuilding'.
# Folder 'PTRC6TLCT91UK1Q6' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC6VBM7FH4B2GH' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC6WQBW724DQTM' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC6WQGBZNUREUM' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC6X3ZH91H5YNT' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRC70ZDP8JM6FW4' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRC72Q7N6CAE7HF' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC733G7JZHZ27K' from 'data' processed and copied to 'des\saute_fry_pan'.
# Folder 'PTRC733MNAK7AT8K' from 'data' processed and copied to 'des\storage_rack'.
# Folder 'PTRC77L2X17V53E3' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC77L7CTUJHUF3' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC79B99G8Y4HRE' from 'data' processed and copied to 'des\kick_scooter'.
# Folder 'PTRC7BR2DTCW8AZ5' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC7BR7VHZJL1Z5' from 'data' processed and copied to 'des\outbuilding'.
# Folder 'PTRC7BRCB9J8YQ05' from 'data' processed and copied to 'des\turntable'.
# Folder 'PTRC7BRYZD099DN5' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC7DHQB5LFDYRD' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC7F8JKY8C6ZWQ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC7GMUJJJ5TUPU' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC7H0K14XQRJ2W' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC7JCWAU7YQ694' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC7KR72KPU6PV5' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRC7KRVYXAN0BN5' from 'data' processed and copied to 'des\storage_box'.
# Folder 'PTRC7KRXF1ZMV076' from 'data' processed and copied to 'des\trash_can'.
# Folder 'PTRC7L4UVQ6P7GQB' from 'data' processed and copied to 'des\saute_fry_pan'.
# Folder 'PTRC7MGABLUHKY9H' from 'data' processed and copied to 'des\clothes_rack'.
# Folder 'PTRC7MGFTBE7XMAJ' from 'data' processed and copied to 'des\book_document_stand'.
# Folder 'PTRC7R069UZH8WN2' from 'data' processed and copied to 'des\speakers'.
# Folder 'PTRC7TCGNRU53DN6' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC7V4B4K4LDBYD' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC7V4MB0T6FFDF' from 'data' processed and copied to 'des\sport_table_game'.
# Folder 'PTRC7WG877TKTT8M' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC814BZRRR34TA' from 'data' processed and copied to 'des\countertop_griddle_appliance'.
# Folder 'PTRC82GBE7D187QE' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC82GCFKM4M1FE' from 'data' processed and copied to 'des\chair'.
# Folder 'PTRC83WPZMUZHBKJ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC85L7349UHU7V' from 'data' processed and copied to 'des\chair'.
# Folder 'PTRC860KCN7KE7LY' from 'data' processed and copied to 'des\thermos'.
# Folder 'PTRC89476UB8RZGC' from 'data' processed and copied to 'des\basket'.
# Folder 'PTRC8CXQ6BMB4YQ8' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC8D98D174W9AD' from 'data' processed and copied to 'des\rice_cookers'.
# Folder 'PTRC8F184R5KFR6K' from 'data' processed and copied to 'des\outbuilding'.
# Folder 'PTRC8GD25A68MUBW' from 'data' processed and copied to 'des\outbuilding'.
# Folder 'PTRC8GD6E8T8XCYV' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC8KHZ9RATKTP7' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC8LWD9WGPGCEC' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC8M91J04ADQVF' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC8P0EK1PTT0LU' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRC8RRFB5VBR960' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC8T4E8YQDZE96' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC8T4N8575JLK8' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRC8UHYRDA54C98' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC8VWYPKDARB2E' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC8XM1ZT7UJ96N' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC8Y0THLTLAGHX' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC8ZCLGYL3P2P1' from 'data' processed and copied to 'des\bassinet'.
# Folder 'PTRC91WFV8H3LHQA' from 'data' processed and copied to 'des\outbuilding'.
# Folder 'PTRC929V9KEJL2JD' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRC9403NENQZ9KQ' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC974Y12U8FCY4' from 'data' processed and copied to 'des\food_processor'.
# Folder 'PTRC9AXN3NYEXKHY' from 'data' processed and copied to 'des\air_purifier'.
# Folder 'PTRC9CNGTP9WRLR7' from 'data' processed and copied to 'des\storage_box'.
# Folder 'PTRC9EE147DA9YJE' from 'data' processed and copied to 'des\cellular_phone'.
# Folder 'PTRC9EEYWN0DD7NE' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC9FTGFMAHY1DL' from 'data' processed and copied to 'des\thermos'.
# Folder 'PTRC9FTVKAPN4DLL' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRC9HJ4G32KC76V' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC9JXCA1XXWZK2' from 'data' processed and copied to 'des\air_conditioner'.
# Folder 'PTRC9JXG902PTUR0' from 'data' processed and copied to 'des\stool_seating'.
# Folder 'PTRC9M1ALA14W3CE' from 'data' processed and copied to 'des\dresser'.
# Folder 'PTRC9ND010XLFXHN' from 'data' processed and copied to 'des\food_dehydrator'.
# Folder 'PTRC9NDYHX8LL8YL' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC9PT27KXDZH6P' from 'data' processed and copied to 'des\countertop_griddle_appliance'.
# Folder 'PTRC9Q558VNVRW4V' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRC9Q5B7BQEKF0X' from 'data' processed and copied to 'des\workbench'.
# Folder 'PTRC9RH88R765EC1' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRC9RHYM7G1UQQ2' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRC9W1BRGE3ZP7H' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC9W1G770RBE8H' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRC9Z59T279DLJ0' from 'data' processed and copied to 'des\turntable'.
# Folder 'PTRCA0XZ67N2KAEZ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCA19HXMQRUGV5' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCA2NY1240EB96' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRCA31HYA5DRN4D' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCA4DDERMW0XWK' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCA7HQW2BCL7KY' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCA999PBYMJE86' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCABPP767G1ZDW' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCABPVNYU6CPEW' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCADEU6M33EA56' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCAGJ2PBWWHJDL' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCAHYXZ9R6L9DR' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCAP6GK47U176K' from 'data' processed and copied to 'des\refrigeration_appliance'.
# Folder 'PTRCATAR3T0L4FF0' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCATAU02P77P6Y' from 'data' processed and copied to 'des\animal_cage'.
# Folder 'PTRCAUNAHAK4ZYF5' from 'data' processed and copied to 'des\speakers'.
# Folder 'PTRCAZJ2THG07TXU' from 'data' processed and copied to 'des\refrigerator'.
# Folder 'PTRCAZJ7882NKHYU' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCB3U5KWB1X6NA' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCB6YWH54YFCQP' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCB7A88PXZG6JV' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCB8N86W0434B1' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCB92FALUD1H54' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCBBFJ239YJDAV' from 'data' processed and copied to 'des\countertop_griddle_appliance'.
# Folder 'PTRCBCV3PGG3AEP1' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCBFZ0UYLL8C2C' from 'data' processed and copied to 'des\chair'.
# Folder 'PTRCBGBCE2M1KV6G' from 'data' processed and copied to 'des\workbench'.
# Folder 'PTRCBHP651DLU0MQ' from 'data' processed and copied to 'des\electric_water_boiler'.
# Folder 'PTRCBHPBMT095PNQ' from 'data' processed and copied to 'des\sandbox'.
# Folder 'PTRCBJ3XV56P9FNV' from 'data' processed and copied to 'des\workbench'.
# Folder 'PTRCBKFD13BB96T0' from 'data' processed and copied to 'des\personal_computer'.
# Folder 'PTRCBNK2E9F9YP9B' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCBPYU4HTMD99K' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCBPYX25PBXARJ' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCBQBF3BQZH4KN' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCBUF2ETDQE1L1' from 'data' processed and copied to 'des\barbecue_grill'.
# Folder 'PTRCBUFXZ1T12AL1' from 'data' processed and copied to 'des\saute_fry_pan'.
# Folder 'PTRCBVU0A81N8CZ7' from 'data' processed and copied to 'des\shelf'.
# Folder 'PTRCBVUVVGF0WNY7' from 'data' processed and copied to 'des\aroma_diffuser'.
# Folder 'PTRCBVUYDZB34478' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCBZAZVLQ875YT' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCC1U0VG7LKGE3' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCC4YU6R51NR1G' from 'data' processed and copied to 'des\guitars'.
# Folder 'PTRCC5BJD5G9NC7J' from 'data' processed and copied to 'des\saute_fry_pan'.
# Folder 'PTRCC6P6WQQ2Q8CP' from 'data' processed and copied to 'des\refrigerator'.
# Folder 'PTRCC72UJTPFGG9U' from 'data' processed and copied to 'des\storage_box'.
# Folder 'PTRCC8FF4EL6BRD0' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCC8FTXU91RLFZ' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRCC9UL2Z278B33' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCCAVD7VD5BGTT' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCCAVV95P01WER' from 'data' processed and copied to 'des\wall_art'.
# Folder 'PTRCCEC815XRECT6' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCCQ3347FFYABL' from 'data' processed and copied to 'des\table'.
# Folder 'PTRCCRFA1WL6BVZU' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCCWZJNEYJ53EA' from 'data' processed and copied to 'des\barbecue_grill'.
# Folder 'PTRCCWZP45H8GUFA' from 'data' processed and copied to 'des\storage_box'.
# Folder 'PTRCCZ35R5AAGT0R' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCD07DQ9256ALX' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCD4QTMQ1H94MC' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCD6FJMZ8J6EXP' from 'data' processed and copied to 'des\air_purifier'.
# Folder 'PTRCDB0ZZKJQXK5R' from 'data' processed and copied to 'des\shelf'.
# Folder 'PTRCDE4N6DLRENW7' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCDMQT0XM7LY86' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCDN4ULHMPTUAB' from 'data' processed and copied to 'des\cellular_phone'.
# Folder 'PTRCDPG3JX7L0YDJ' from 'data' processed and copied to 'des\food_mixer'.
# Folder 'PTRCDQVGXU71RAKL' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCDR8GBL8UV16P' from 'data' processed and copied to 'des\animal_cage'.
# Folder 'PTRCDUZGGHP81VF4' from 'data' processed and copied to 'des\speakers'.
# Folder 'PTRCDWQK5WJD4CT9' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCDX309FGXPA7E' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCDYG76BBGJJKJ' from 'data' processed and copied to 'des\chair'.
# Folder 'PTRCDYGCZ0DC9Y0K' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCDYGH4UHV8YLJ' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRCE00ZA4UKK8PU' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCE1CX0QHVAFM0' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCE4GZWVQ8YUED' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRCE5VVJ46DA8LK' from 'data' processed and copied to 'des\pressure_cooker'.
# Folder 'PTRCE68Y7EM38P4N' from 'data' processed and copied to 'des\personal_computer'.
# Folder 'PTRCE8ZZGZV0Q7VY' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCE9C9YALNUXH3' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCEC5QF3EWP1XX' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCEDHRD9H1A0P3' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCEEW01QMR5DD9' from 'data' processed and copied to 'des\food_blender'.
# Folder 'PTRCEEWWLC956G38' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCEF94KZJYUBXB' from 'data' processed and copied to 'des\turntable'.
# Folder 'PTRCEF9C0B3AP3CA' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCEF9VDY3F5059' from 'data' processed and copied to 'des\wall_art'.
# Folder 'PTRCEF9YMGHC1R19' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCEGM46VYTNTJG' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCEGMVARZHC67F' from 'data' processed and copied to 'des\wall_art'.
# Folder 'PTRCEH0E7ZZXNH3N' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCEJDQX10KBF7P' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCEKRBP6GGC82W' from 'data' processed and copied to 'des\toaster'.
# Folder 'PTRCEKRQ54KYA4DY' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCEL4QTD7WJCT2' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCEMH8XNQ1FQL7' from 'data' processed and copied to 'des\coffee_maker'.
# Folder 'PTRCEMH93GPQJW17' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCEP8KAH40QTUG' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCEQMACEQM219H' from 'data' processed and copied to 'des\saute_fry_pan'.
# Folder 'PTRCEQMFU5ABERAJ' from 'data' processed and copied to 'des\desk'.
# Folder 'PTRCER076G5GGLXQ' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCER0LH0GCR4HR' from 'data' processed and copied to 'des\speakers'.
# Folder 'PTRCEV417VLQ7533' from 'data' processed and copied to 'des\table'.
# Folder 'PTRCEV4ND4PRDHB5' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCEWGQH4RL3LJB' from 'data' processed and copied to 'des\drinking_cup'.
# Folder 'PTRCEXW7602YYX8D' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCEXWDJN54029C' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCEY8B9M2G52XJ' from 'data' processed and copied to 'des\speakers'.
# Folder 'PTRCEY8RAL58EPVH' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCEY8WWE9E3YVJ' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCEZL0HJ09LQMT' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCF0RM4991D7ZV' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCF0RQ2X7QX8EU' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCF3WMT7ANKMM8' from 'data' processed and copied to 'des\toaster'.
# Folder 'PTRCF3WP0DHF2KT8' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCF48YGEWK7MRD' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCF60UY851GK1L' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCF60ZD0RQV91L' from 'data' processed and copied to 'des\storage_rack'.
# Folder 'PTRCF7CNDBFEC12T' from 'data' processed and copied to 'des\shelf'.
# Folder 'PTRCF8RUZXKPERAW' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCFA58FYDUWDGN' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCFA5FABYWDECP' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCFD9RKUNNXJM1' from 'data' processed and copied to 'des\animal_cage'.
# Folder 'PTRCFENG8J8NZ7X5' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCFF1B9LHC6DK9' from 'data' processed and copied to 'des\wall_art'.
# Folder 'PTRCFF1GQC41H4K9' from 'data' processed and copied to 'des\wall_art'.
# Folder 'PTRCFF1Z4Y46Z1C9' from 'data' processed and copied to 'des\shelf'.
# Folder 'PTRCFGDT01D9GRUH' from 'data' processed and copied to 'des\fireplace'.
# Folder 'PTRCFJ5J7AAVXX7Q' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCFJ5LKZ77272R' from 'data' processed and copied to 'des\food_blender'.
# Folder 'PTRCFJ5ZJ6VTK8JR' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCFKHKVKXT55KW' from 'data' processed and copied to 'des\speakers'.
# Folder 'PTRCFKHQABHGHWLW' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCFLXHXP062KCZ' from 'data' processed and copied to 'des\saute_fry_pan'.
# Folder 'PTRCFLXW1CDC9YJZ' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCFM9DQE7Y3B95' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCFP1NGRV9MT5D' from 'data' processed and copied to 'des\animal_cage'.
# Folder 'PTRCFQD0BE5TZ5ZK' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCFT5FBACUA7XR' from 'data' processed and copied to 'des\bottle_rack'.
# Folder 'PTRCFT5Y1TV54U4T' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCFUH4EQJ03GYZ' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCFVWFBR2LUNG5' from 'data' processed and copied to 'des\chair'.
# Folder 'PTRCFW98711HR3M9' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCFW9EWLLX6Y39' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCFW9KBC7KJN49' from 'data' processed and copied to 'des\food_processor'.
# Folder 'PTRCFXMQ8HFJ2F3D' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCFZDWKGQ9M0NM' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCG0HRVABT876U' from 'data' processed and copied to 'des\speakers'.
# Folder 'PTRCG1XG8GMPB0TX' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCG3MX4EPNFQK8' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCG5DLJJD5167H' from 'data' processed and copied to 'des\toilet'.
# Folder 'PTRCG9WRFYC0GYZ2' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCGAYMKNBFHUVK' from 'data' processed and copied to 'des\cabinet'.
# Folder 'PTRCGD2870GDTEA0' from 'data' processed and copied to 'des\tent'.
# Folder 'PTRCGEE2G9T2JQX5' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCGFT24HE1TZ99' from 'data' processed and copied to 'des\stool_seating'.
# Folder 'PTRCGFTC20LDHDBA' from 'data' processed and copied to 'des\basket'.
# Folder 'PTRCGFTHHR72V3BA' from 'data' processed and copied to 'des\electric_water_boiler'.
# Folder 'PTRCGNE2A6GQWUL8' from 'data' processed and copied to 'des\electric_fan'.
# Folder 'PTRCGNEGUGU97GN9' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCGNEHPDATYYN8' from 'data' processed and copied to 'des\thermos'.
# Folder 'PTRCGNEMEP5J9JDA' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCGPT5GX0RCJ9D' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCGRJ4MNYXK9HP' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCGRJE97M3XZ5M' from 'data' processed and copied to 'des\storage_rack'.
# Folder 'PTRCGTX333K6QCGU' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCGTXZZMPT55KV' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCGW121KWWWPU8' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCGZ564W9201RM' from 'data' processed and copied to 'des\sofa'.
# Folder 'PTRCGZ5TZVNUEWVM' from 'data' processed and copied to 'des\saute_fry_pan'.
# Folder 'PTRCH0AN8HR210CQ' from 'data' processed and copied to 'des\toaster'.
# Folder 'PTRCH0AZFYEM44UR' from 'data' processed and copied to 'des\ice_cream_maker'.
# Folder 'PTRCH1NHQZ8HA94W' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCH2182YVLZA13' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCH3ECFCU3J335' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCH3ELVQBGEVK4' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCH3EQ93P2CRW4' from 'data' processed and copied to 'des\electric_water_boiler'.
# Folder 'PTRCH4TWUG5G1RDB' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCH7X8RJAW2XYQ' from 'data' processed and copied to 'des\humidifier'.
# Folder 'PTRCH7XC2FYVBGJQ' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCH7XHH7HJP6JQ' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCHAPM67FTRM6K' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCHAPQ4VDG9NMJ' from 'data' processed and copied to 'des\laundry_hamper'.
# Folder 'PTRCHB220WX3ZV6P' from 'data' processed and copied to 'des\clothes_rack'.
# Folder 'PTRCHE6K1HMJ44K7' from 'data' processed and copied to 'des\air_conditioner'.
# Folder 'PTRCHFKYYRV080V8' from 'data' processed and copied to 'des\storage_box'.
# Folder 'PTRCHJP0ZBU0KRCN' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCHN6Z0FYF1D79' from 'data' processed and copied to 'des\guitars'.
# Folder 'PTRCHPJY92L13BQD' from 'data' processed and copied to 'des\baby_seat'.
# Folder 'PTRCHTNBEZQ37MPU' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCHU234ERA3XEY' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCHU27DCDACG1X' from 'data' processed and copied to 'des\guitars'.
# Folder 'PTRCHVEDZQUQ0GJ4' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCHX6T1BB579QB' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCHX6YG3XUK0RB' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCHYJQKH9T94YG' from 'data' processed and copied to 'des\monitor'.
# Folder 'PTRCHYJUU2NP5WUG' from 'data' processed and copied to 'des\bed_frame'.
# Folder 'PTRCHZX4NQZ7F9MN' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCHZX94FKXUZNN' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCHZXUR8RVRVLN' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCHZXZ7ZCJ4JMN' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCJ2UJTNMR1LU0' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCJ36JEY8P9V64' from 'data' processed and copied to 'des\basket'.
# Folder 'PTRCJ4JGZ36CBQDA' from 'data' processed and copied to 'des\cellular_phone'.
# Folder 'PTRCJ5Y0Z960YH8D' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCJ6AC1RF8B2GL' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCJ82Q20QJ61ZU' from 'data' processed and copied to 'des\chair'.
# Folder 'PTRCJBVKPFZX8HKN' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCJC7FH65N99FW' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCJEZWQ8DP6ED4' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCJFBP0GQCZQ09' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCJH30UJUWATBH' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCJKU549CTGL7V' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCJKUAFK8V5YHV' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCJKUFXAVJHNJV' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCJKUWDM53VBLW' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCJL7BFB9YKERW' from 'data' processed and copied to 'des\cellular_phone'.
# Folder 'PTRCJNYDNZ5JKVF9' from 'data' processed and copied to 'des\personal_computer'.
# Folder 'PTRCJPBR1KLURTVC' from 'data' processed and copied to 'des\guitars'.
# Folder 'PTRCJYA0R9W7FW6F' from 'data' processed and copied to 'des\bottle'.
# Folder 'PTRCJZP1HBMAB4YL' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCJZPEVUZ5KMKM' from 'data' processed and copied to 'des\sport_table_game'.
# Folder 'PTRCJZPKAKKVYBLM' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCK2K35FQMXNT1' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCK3Y2XUV3EG56' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCK3YBH1B6CD25' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCK62GYLFN974K' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCK7F35ZM3C04P' from 'data' processed and copied to 'des\workbench'.
# Folder 'PTRCK7FTT47XLHZM' from 'data' processed and copied to 'des\chair'.
# Folder 'PTRCKA8VK8NNZHKJ' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCKC0D37JN572R' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCKDC7GYLYLWDZ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCKEQ8A16KY963' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCKEQ9BDEPB3X3' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCKGG1U7JCQ50C' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCKHVR1QEVPV6J' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCKJ8PTY118JJL' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRCKKL2C22FL1NQ' from 'data' processed and copied to 'des\fountain'.
# Folder 'PTRCKLZ9K0XGT2F0' from 'data' processed and copied to 'des\thermos'.
# Folder 'PTRCKMCGX1TNWW00' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCKMCV65XERLX1' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCKQG0LR1XMF0F' from 'data' processed and copied to 'des\deep_fryer'.
# Folder 'PTRCKQGV50E89QZF' from 'data' processed and copied to 'des\toilet'.
# Folder 'PTRCKQGY3MCYTTEE' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCKULP7Q4JE4WU' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCL0LXKDUK977P' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCL1Z3JAHQKMMU' from 'data' processed and copied to 'des\cellular_phone'.
# Folder 'PTRCL3Q0TTQ9N454' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCL5GX9Z8UCV5B' from 'data' processed and copied to 'des\storage_rack'.
# Folder 'PTRCL6VEZ12E77VJ' from 'data' processed and copied to 'des\thermos'.
# Folder 'PTRCL8LAKB4G6GVT' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCLA0EVY81J1JJ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCLBD95RGN5ULK' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCLBDU3F6TFEZL' from 'data' processed and copied to 'des\humidifier'.
# Folder 'PTRCLCR3XR87C02T' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCLD4CF5UFYVRY' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCLG8MVQ3QQJ1A' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCLHM1P3ZWCC9F' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCLHMW8BD70M8F' from 'data' processed and copied to 'des\rice_cookers'.
# Folder 'PTRCLJ04KX0QGCHL' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCLKCHCV0VXZ2Q' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCLLR0G4H0UBXW' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCLM4JF8VPMRTZ' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCLNGY4XAE6GL8' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCLPW0AHA7N489' from 'data' processed and copied to 'des\food_blender'.
# Folder 'PTRCLPW1BWHA3XZ9' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCLVQ0C227LLMZ' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCLVQ1DEAB1DCZ' from 'data' processed and copied to 'des\freestanding_shelter'.
# Folder 'PTRCLVQVXAGJ9WLZ' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRCLYVM776VZCHD' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCLZ8WGRZUZXQH' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCM1RB2U325Z9P' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCM4W4BRUDWF64' from 'data' processed and copied to 'des\dresser'.
# Folder 'PTRCM4WHUPXVUBH6' from 'data' processed and copied to 'des\thermos'.
# Folder 'PTRCM6LWYU0UH68J' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCM70LWM3YJWQK' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCM8C8MTKVKNLR' from 'data' processed and copied to 'des\shelf'.
# Folder 'PTRCM8C9Z294B6QT' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCM8CYQADGW8JR' from 'data' processed and copied to 'des\barbecue_grill'.
# Folder 'PTRCME95GMQX2140' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCME992FV3PA51' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCMFM8YXG2HNG8' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCMHDZY06UFWQF' from 'data' processed and copied to 'des\lap_desk'.
# Folder 'PTRCMMW1LVRT1VL0' from 'data' processed and copied to 'des\dresser'.
# Folder 'PTRCMMWG5HAFTBD1' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCMN93D9PZ9W34' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCMPM9G9XLWVG9' from 'data' processed and copied to 'des\laundry_hamper'.
# Folder 'PTRCMPMQ1YF9LB99' from 'data' processed and copied to 'des\personal_computer'.
# Folder 'PTRCMPMWGP2YZ199' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCMTRHGBY605VQ' from 'data' processed and copied to 'des\food_blender'.
# Folder 'PTRCMU4U12QHZU9V' from 'data' processed and copied to 'des\rice_cookers'.
# Folder 'PTRCMU4ZGUB7AJAW' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCMVHCXT0JX9DZ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCMVHV5X93NVGY' from 'data' processed and copied to 'des\storage_rack'.
# Folder 'PTRCN39N4MHEX2G1' from 'data' processed and copied to 'des\storage_box'.
# Folder 'PTRCN39NEK0L9RX2' from 'data' processed and copied to 'des\turntable'.
# Folder 'PTRCN4MJL30W5A96' from 'data' processed and copied to 'des\storage_hook'.
# Folder 'PTRCN4MLU96NM9D7' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCN6DU2G60B2QD' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRCN7RC3UPXYYKM' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCN84FU6Z5CL4Q' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCN9HYL6T0HFUV' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCNAJ2YLVDA1QE' from 'data' processed and copied to 'des\video_game_controller'.
# Folder 'PTRCNBXU6GYZNHML' from 'data' processed and copied to 'des\speakers'.
# Folder 'PTRCNCAGB5U0WHCP' from 'data' processed and copied to 'des\storage_box'.
# Folder 'PTRCNDN9WAMW1HDX' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCNDNCVYJKJKVV' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCNFEWLGPNP614' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCNGTDPPJWT5X8' from 'data' processed and copied to 'des\thermos'.
# Folder 'PTRCNKXKA4L2R5EP' from 'data' processed and copied to 'des\cellular_phone'.
# Folder 'PTRCNL9VZYYW0CVV' from 'data' processed and copied to 'des\guitars'.
# Folder 'PTRCNMNRUWVGFVFY' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCNN191JFA8512' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCNN1A3XNDMZR2' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRCNTHJHEB8XC3M' from 'data' processed and copied to 'des\storage_box'.
# Folder 'PTRCNTHT7PBU5UZM' from 'data' processed and copied to 'des\bench'.
# Folder 'PTRCNTHVW9QDPV8P' from 'data' processed and copied to 'des\outbuilding'.
# Folder 'PTRCNUX3PEAKMBCT' from 'data' processed and copied to 'des\keyboards'.
# Folder 'PTRCNWM6TZNNB724' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCNZRNWGQEZJHH' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCP2NNYGA779QW' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCP313227PU751' from 'data' processed and copied to 'des\turntable'.
# Folder 'PTRCP4DFUM0QV106' from 'data' processed and copied to 'des\trash_can'.
# Folder 'PTRCP4DU87V3D4L8' from 'data' processed and copied to 'des\air_conditioner'.
# Folder 'PTRCP656ZJN7VDPE' from 'data' processed and copied to 'des\laundry_hamper'.
# Folder 'PTRCP65JE5HKEGAG' from 'data' processed and copied to 'des\turntable'.
# Folder 'PTRCP65PWW48R6AG' from 'data' processed and copied to 'des\freestanding_shelter'.
# Folder 'PTRCP65VBMQY4WBG' from 'data' processed and copied to 'des\workbench'.
# Folder 'PTRCP7H4N6BGLLLL' from 'data' processed and copied to 'des\storage_rack'.
# Folder 'PTRCP8XLC3MUFXAP' from 'data' processed and copied to 'des\clothes_rack'.
# Folder 'PTRCPAAP91VZN45D' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCPAAVQTFN1U6D' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCPEU67P5AF9BZ' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCPF6GTFZMDYR3' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCPJAK4YDV3CPJ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCPKNVY8F90YTQ' from 'data' processed and copied to 'des\food_blender'.
# Folder 'PTRCPKNY1B5J7BZP' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCPL2HZTVTYDJT' from 'data' processed and copied to 'des\camcorder'.
# Folder 'PTRCPME4DNMD7N9X' from 'data' processed and copied to 'des\storage_rack'.
# Folder 'PTRCPQJX0GVX9VKD' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCPRX56KQV274G' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCPRXJNJUA13FJ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCPRXR1J4KG27G' from 'data' processed and copied to 'des\clothes_rack'.
# Folder 'PTRCPUNGG115FBLT' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCPV1F8C6L04YY' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCPXTD2VDGFC36' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCPY5U1ZKDCYTB' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCQ0NYDH05VJ4M' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCQ2EBFR9FPJLW' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCQ3TL4KLAYR01' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCQ7AF9TL4CCEG' from 'data' processed and copied to 'des\barbecue_grill'.
# Folder 'PTRCQ91C7HWQ37HW' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCQA34QEQ0FVDC' from 'data' processed and copied to 'des\microphone'.
# Folder 'PTRCQA3ZQ2B456GE' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCQBFZBZQZ0M5J' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCQCU1BW9AE7CQ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCQCUCAQPTHE5P' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCQFY26L9LNTF4' from 'data' processed and copied to 'des\refrigerator'.
# Folder 'PTRCQFYG8JCDZDD3' from 'data' processed and copied to 'des\desk'.
# Folder 'PTRCQFYJRN1CU2Y4' from 'data' processed and copied to 'des\ice_maker'.
# Folder 'PTRCQGBLXWT2XWW6' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCQGBRH34BZYL7' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCQLUE1W31YRKR' from 'data' processed and copied to 'des\storage_rack'.
# Folder 'PTRCQM6ZQA5Q6Y0Y' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCQPYGX0AFL5C5' from 'data' processed and copied to 'des\animal_cage'.
# Folder 'PTRCQQAAT3KH4VUD' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCQQAKN7JTEG5D' from 'data' processed and copied to 'des\stringed_instruments'.
# Folder 'PTRCQRP3CG37NKKG' from 'data' processed and copied to 'des\scanner'.
# Folder 'PTRCQRP7BG80KERE' from 'data' processed and copied to 'des\bed_frame'.
# Folder 'PTRCQRP8U7NX19KG' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCQT2U4LQXL7LL' from 'data' processed and copied to 'des\table'.
# Folder 'PTRCQUEW3515LZ4R' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCQXJ8GLEBQ6T8' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCQZA074V0NGCE' from 'data' processed and copied to 'des\cabinet'.
# Folder 'PTRCR0FABEZ3DU2J' from 'data' processed and copied to 'des\utility_cart_wagon'.
# Folder 'PTRCR0FK226R12NJ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCR1UFWTDJ2UKR' from 'data' processed and copied to 'des\aroma_diffuser'.
# Folder 'PTRCR26T5ZYR1KAV' from 'data' processed and copied to 'des\barbecue_grill'.
# Folder 'PTRCR4Y6BPZNJYG3' from 'data' processed and copied to 'des\food_mixer'.
# Folder 'PTRCR6PR1GUCUTEB' from 'data' processed and copied to 'des\electric_water_boiler'.
# Folder 'PTRCR9UATK9PZ54R' from 'data' processed and copied to 'des\electric_water_boiler'.
# Folder 'PTRCRCLZCAX3B73N' from 'data' processed and copied to 'des\speakers'.
# Folder 'PTRCRDZ0WF0JAXGT' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCRDZ5B7K8MLHT' from 'data' processed and copied to 'des\personal_computer'.
# Folder 'PTRCRG3DGQBEG9K9' from 'data' processed and copied to 'des\robotic_vacuum_cleaner'.
# Folder 'PTRCRG3UC7NK3HU7' from 'data' processed and copied to 'des\storage_rack'.
# Folder 'PTRCRG3W1R35LJ39' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCRHFR2UCVUQQD' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCRK7M0D46JHVN' from 'data' processed and copied to 'des\juicer'.
# Folder 'PTRCRLKQPD6BLCNT' from 'data' processed and copied to 'des\countertop_griddle_appliance'.
# Folder 'PTRCRMZ27FC7FNRX' from 'data' processed and copied to 'des\trash_can'.
# Folder 'PTRCRNBQ1Z26W8B3' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCRPPABD46F6C7' from 'data' processed and copied to 'des\refrigerator'.
# Folder 'PTRCRXBRQT8BYT24' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCRYP4M6Z21RBA' from 'data' processed and copied to 'des\sport_table_game'.
# Folder 'PTRCT1K8B2HLEYLP' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCT2ZA00Q6ZLDU' from 'data' processed and copied to 'des\cellular_phone'.
# Folder 'PTRCT531X9H4HTE7' from 'data' processed and copied to 'des\clothes_rack'.
# Folder 'PTRCT53RB311KWH8' from 'data' processed and copied to 'des\guitars'.
# Folder 'PTRCT7U73XKHE2AJ' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCT9KJ8W574T2T' from 'data' processed and copied to 'des\freestanding_shelter'.
# Folder 'PTRCTB0H3ZDYKBGE' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCTB0T90VD9M7F' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCTDQ9HLVRJPVU' from 'data' processed and copied to 'des\sport_table_game'.
# Folder 'PTRCTH82TXC39U89' from 'data' processed and copied to 'des\sunglasses'.
# Folder 'PTRCTJLFKVC7PFUE' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCTPGJ4U6QE8E5' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCTPGPKKTETYF5' from 'data' processed and copied to 'des\coffee_maker'.
# Folder 'PTRCTPGTNNFQZBM4' from 'data' processed and copied to 'des\electric_water_boiler'.
# Folder 'PTRCTR7WTK2X202F' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCTVBW9N4U599U' from 'data' processed and copied to 'des\sofa'.
# Folder 'PTRCU0Z7AC2ZEHKK' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCU0Z9250ZVDLH' from 'data' processed and copied to 'des\saute_fry_pan'.
# Folder 'PTRCU5VCY2AQYWM9' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCU671AK10P7UC' from 'data' processed and copied to 'des\barbecue_grill'.
# Folder 'PTRCUEWRNLJVZF6W' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCUF99HBUWXXA0' from 'data' processed and copied to 'des\trash_can'.
# Folder 'PTRCUH05M1XAEEFA' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCUNWB5MNJM8HZ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCUP8X1WNYYKD6' from 'data' processed and copied to 'des\speakers'.
# Folder 'PTRCUV47TE25EZ2U' from 'data' processed and copied to 'des\slow_cooker'.
# Folder 'PTRCUWGNB6099FNX' from 'data' processed and copied to 'des\chair'.
# Folder 'PTRCUXV2KVFA6Y23' from 'data' processed and copied to 'des\bed'.
# Folder 'PTRCV143AGW42QDL' from 'data' processed and copied to 'des\laundry_hamper'.
# Folder 'PTRCV48KARCGU723' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCV60AAV28QEBB' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCV60Y0PYGWPEA' from 'data' processed and copied to 'des\saute_fry_pan'.
# Folder 'PTRCV8RGN5J3QRMJ' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCV94UV3JXUMLR' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCVA50DQT325NB' from 'data' processed and copied to 'des\utility_cart_wagon'.
# Folder 'PTRCVA5EA748NEX9' from 'data' processed and copied to 'des\outbuilding'.
# Folder 'PTRCVCXFHPHLPRLJ' from 'data' processed and copied to 'des\countertop_griddle_appliance'.
# Folder 'PTRCVCXGVZ7WF9QK' from 'data' processed and copied to 'des\air_purifier'.
# Folder 'PTRCVD90X623J8LP' from 'data' processed and copied to 'des\cellular_phone'.
# Folder 'PTRCVD9Y0XCHF0WQ' from 'data' processed and copied to 'des\ice_maker'.
# Folder 'PTRCVENXR4ZP0P8R' from 'data' processed and copied to 'des\barbecue_grill'.
# Folder 'PTRCVF183HQ4RYX0' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCVF1H0MPD3J80' from 'data' processed and copied to 'des\camcorder'.
# Folder 'PTRCVJ5XZ22VHHHE' from 'data' processed and copied to 'des\camera_digital'.
# Folder 'PTRCVKH9DQCP6LYH' from 'data' processed and copied to 'des\bed_frame'.
# Folder 'PTRCVKHQTY5Q8Q0H' from 'data' processed and copied to 'des\sofa'.
# Folder 'PTRCVLXZ2FYP897M' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCVM9RWB1KZHQR' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCVNM4XU9TC2ZY' from 'data' processed and copied to 'des\noise_machine'.
# Folder 'PTRCVP15HE99HY12' from 'data' processed and copied to 'des\bottle'.
# Folder 'PTRCVP1VLY2XUH02' from 'data' processed and copied to 'des\chair'.
# Folder 'PTRCVQDDP5X4XGW6' from 'data' processed and copied to 'des\table'.
# Folder 'PTRCVQDXKGD6U9G8' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCVRR804N0GDYB' from 'data' processed and copied to 'des\baking_pan'.
# Folder 'PTRCVRR9GW4WY8RD' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCW0HFEFTN9NJG' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCW1X1BXGX0Q4J' from 'data' processed and copied to 'des\laundry_appliance'.
# Folder 'PTRCW29PGPX66UVR' from 'data' processed and copied to 'des\juicer'.
# Folder 'PTRCW3MC094Z8P1W' from 'data' processed and copied to 'des\air_fryer'.
# Folder 'PTRCW5DQA3ND2L75' from 'data' processed and copied to 'des\dehumidifier'.
# Folder 'PTRCW5DWFXTW1LU4' from 'data' processed and copied to 'des\saute_fry_pan'.
# Folder 'PTRCW6R15QZXC01B' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCW75MZ35MUGMD' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCW9W7R513B0JT' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCW9WKRCPNV01R' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCW9WPWUK2E7XQ' from 'data' processed and copied to 'des\caddy'.
# Folder 'PTRCWAYJHU3L07Y6' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCWG6E6KG8TYG2' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCWHJ7PD20J5T9' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCWHJC64MPXVU9' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCWHJGF29N6DE9' from 'data' processed and copied to 'des\speakers'.
# Folder 'PTRCWHJV9T6M0267' from 'data' processed and copied to 'des\desk'.
# Folder 'PTRCWJXRUZ4A2XDD' from 'data' processed and copied to 'des\table'.
# Folder 'PTRCWKALL6KQPTKG' from 'data' processed and copied to 'des\electric_water_boiler'.
# Folder 'PTRCWM1CT8RFP88U' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCWM1MHX04AHWU' from 'data' processed and copied to 'des\guitars'.
# Folder 'PTRCWM1YKVY3P9LV' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCWNEXGHAXYBPX' from 'data' processed and copied to 'des\coffee_maker'.
# Folder 'PTRCWPTCUX63LEJ3' from 'data' processed and copied to 'des\scanner'.
# Folder 'PTRCWQ5LFDAVFV78' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCWRJVDMCHPWAC' from 'data' processed and copied to 'des\coffee_maker'.
# Folder 'PTRCWZ5L4U8W3K7A' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCX55X46CE31K4' from 'data' processed and copied to 'des\wall_art'.
# Folder 'PTRCX89H3F1JQCFK' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCXCFTAQWZFRKH' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCXJP8F6Y1XT2B' from 'data' processed and copied to 'des\fireplace'.
# Folder 'PTRCXK22RTGU3WDH' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCXN6TVH1BBE5X' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCXPJVNLL0MUY2' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCXQYHVLQ48LD5' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCXU2VXRD0KBYK' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCXYJRTKNZ13M3' from 'data' processed and copied to 'des\furniture_cart'.
# Folder 'PTRCXYJZREYM8F84' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCXZX23L69DJLB' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCY02BQ5UGP0FE' from 'data' processed and copied to 'des\guitars'.
# Folder 'PTRCY36YHZQ1MZLV' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCY5YDMYFJ9JJ2' from 'data' processed and copied to 'des\bed_frame'.
# Folder 'PTRCY5YZQF4CNAB4' from 'data' processed and copied to 'des\utility_cart_wagon'.
# Folder 'PTRCYAFJ1VVGWK18' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCYDKVFUBW220L' from 'data' processed and copied to 'des\trash_can'.
# Folder 'PTRCYH374J07JNL6' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCYJFB6URNC1JB' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCYJFLR18QAYFA' from 'data' processed and copied to 'des\clothes_rack'.
# Folder 'PTRCYL7Z8MRV6Z2K' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCYNYDP7K18MQV' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCYNYV2ED3ATTV' from 'data' processed and copied to 'des\lap_desk'.
# Folder 'PTRCYR2GC0QHQLTB' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCYTFT7GHT2WLD' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCYV6VA2WWRRBR' from 'data' processed and copied to 'des\air_conditioner'.
# Folder 'PTRCYWKLVPYDJWMV' from 'data' processed and copied to 'des\electric_food_mill_grinder'.
# Folder 'PTRCYWKRAFJ3WKNV' from 'data' processed and copied to 'des\scanner'.
# Folder 'PTRCYZPE1H57YTJ8' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCZ0U6PHMJXR2D' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCZ17LBPGPZFBH' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCZ17RTE3CB6BH' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCZ4BUM62NKREX' from 'data' processed and copied to 'des\clothes_rack'.
# Folder 'PTRCZ62U2516QLW6' from 'data' processed and copied to 'des\suitcase'.
# Folder 'PTRCZ8UED62C5NCH' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCZ8UKVXN2GDDH' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCZ967MED2XZZN' from 'data' processed and copied to 'des\stringed_instruments'.
# Folder 'PTRCZCZWY7H8XAJJ' from 'data' processed and copied to 'des\shoes'.
# Folder 'PTRCZEQ47TQN1WKQ' from 'data' processed and copied to 'des\therapeutic_thermal_compress'.
# Folder 'PTRCZJ75ANAB94VB' from 'data' processed and copied to 'des\home_mirror'.
# Folder 'PTRCZJ7E7R9KKR6B' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCZKLP1XURH89D' from 'data' processed and copied to 'des\countertop_griddle_appliance'.
# Folder 'PTRCZLZLEM1UWQTJ' from 'data' processed and copied to 'des\pressure_cooker'.
# Folder 'PTRCZMBAEZPHDGUQ' from 'data' processed and copied to 'des\sofa'.
# Folder 'PTRCZMBUFRX5ZL5T' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCZNQ4655X1B0U' from 'data' processed and copied to 'des\rug'.
# Folder 'PTRCZNQ798U77Q5T' from 'data' processed and copied to 'des\thermos'.
# Folder 'PTRCZP3V3RJ7MBRZ' from 'data' processed and copied to 'des\camera_digital'.
# Folder 'PTRCZRV1R0H80CG8' from 'data' processed and copied to 'des\faucet'.
# Folder 'PTRCZUKRQWH6HW0K' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCZVZHAXTTPT1N' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCZWBUU9C18MQU' from 'data' processed and copied to 'des\clock'.
# Folder 'PTRCZWBZ90ZPLCRU' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCZXP0D11JAGZ0' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCZXP2AAR5DQPZ' from 'data' processed and copied to 'des\laundry_hamper'.
# Folder 'PTRCZXPXVJ5F20NZ' from 'data' processed and copied to 'des\coffee_maker'.
# Folder 'PTRCZZF5WE2WKC98' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCZZFAC6MKY298' from 'data' processed and copied to 'des\light_fixture'.
# Folder 'PTRCZZFBDJWNBW08' from 'data' processed and copied to 'des\rug'.

# %% [markdown]
# # Classification model

# %%
# Set up the directory for your main dataset folder
#dataset_dir = '/content/des'
dataset_dir = destination_directory
# Set the parameters for your model
image_size = (224, 224)  # Size of input images for the model

# Data preprocessing and augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Load and preprocess the training dataset
train_images = []
train_labels = []
label_mapping = {}

for i, category_folder in enumerate(os.listdir(dataset_dir)):
    category_path = os.path.join(dataset_dir, category_folder)
    if not os.path.isdir(category_path):  # Skip non-directory files
        continue
    if category_folder == '.ipynb_checkpoints':  # Skip any system-generated folders
        continue
    if category_folder.endswith('.json'):  # Skip JSON files
        continue

    label_mapping[i] = category_folder

    for image_name in os.listdir(category_path):
        image_path = os.path.join(category_path, image_name)
        if image_name.endswith('.json'):  # Skip JSON files
            continue
        if os.path.isfile(image_path):  # Skip subdirectories and non-file items
            train_images.append(image_path)
            train_labels.append(i)

# Convert labels to categorical format
num_classes = len(label_mapping)
train_labels = keras.utils.to_categorical(train_labels, num_classes)

# Build the model
model = keras.models.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(num_classes, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(
    train_datagen.flow_from_directory(
        dataset_dir,
        target_size=image_size,
        batch_size=64,
        class_mode='categorical',
        shuffle=True
    ),
    epochs=20
)

# Save the model
model.save('model.h5')

# Print label mapping
print(label_mapping)
# Out:
# Found 4354 images belonging to 97 classes.
# Epoch 1/20
# 69/69 [==============================] - 130s 2s/step - loss: 7.1810 - accuracy: 0.0400
# Epoch 2/20
# 69/69 [==============================] - 113s 2s/step - loss: 4.4985 - accuracy: 0.1348
# Epoch 3/20
# 69/69 [==============================] - 114s 2s/step - loss: 4.4524 - accuracy: 0.1647
# Epoch 4/20
# 69/69 [==============================] - 114s 2s/step - loss: 4.3868 - accuracy: 0.1380
# Epoch 5/20
# 69/69 [==============================] - 111s 2s/step - loss: 4.3548 - accuracy: 0.1649
# Epoch 6/20
# 69/69 [==============================] - 113s 2s/step - loss: 4.3052 - accuracy: 0.1656
# Epoch 7/20
# 69/69 [==============================] - 112s 2s/step - loss: 4.2555 - accuracy: 0.1672
# Epoch 8/20
# 69/69 [==============================] - 116s 2s/step - loss: 4.2099 - accuracy: 0.1638
# Epoch 9/20
# 69/69 [==============================] - 112s 2s/step - loss: 4.1689 - accuracy: 0.1670
# Epoch 10/20
# 69/69 [==============================] - 111s 2s/step - loss: 4.1251 - accuracy: 0.1661
# Epoch 11/20
# 69/69 [==============================] - 111s 2s/step - loss: 4.0835 - accuracy: 0.1661
# Epoch 12/20
# 69/69 [==============================] - 110s 2s/step - loss: 4.0431 - accuracy: 0.1677
# Epoch 13/20
# 69/69 [==============================] - 118s 2s/step - loss: 4.0044 - accuracy: 0.1702
# Epoch 14/20
# 69/69 [==============================] - 115s 2s/step - loss: 3.9699 - accuracy: 0.1672
# Epoch 15/20
# 69/69 [==============================] - 111s 2s/step - loss: 3.9341 - accuracy: 0.1656
# Epoch 16/20
# 69/69 [==============================] - 110s 2s/step - loss: 3.8999 - accuracy: 0.1658
# Epoch 17/20
# 69/69 [==============================] - 109s 2s/step - loss: 3.8667 - accuracy: 0.1670
# Epoch 18/20
# 69/69 [==============================] - 111s 2s/step - loss: 3.8312 - accuracy: 0.1702
# Epoch 19/20
# 69/69 [==============================] - 111s 2s/step - loss: 3.7974 - accuracy: 0.1732
# Epoch 20/20
# 69/69 [==============================] - 111s 2s/step - loss: 3.7667 - accuracy: 0.1711
# C:\Users\admin\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# {0: 'air_conditioner', 1: 'air_fryer', 2: 'air_purifier', 3: 'animal_cage', 4: 'aroma_diffuser', 5: 'baby_seat', 6: 'baking_pan', 7: 'barbecue_grill', 8: 'basket', 9: 'bassinet', 10: 'bed', 11: 'bed_frame', 12: 'bench', 13: 'book_document_stand', 14: 'bottle', 15: 'bottle_rack', 16: 'cabinet', 17: 'caddy', 18: 'camcorder', 19: 'camera_digital', 20: 'cellular_phone', 21: 'chair', 22: 'clock', 23: 'clothes_rack', 24: 'coffee_maker', 25: 'cooking_pot', 26: 'countertop_griddle_appliance', 27: 'deep_fryer', 28: 'dehumidifier', 29: 'desk', 30: 'dresser', 31: 'drinking_cup', 32: 'electric_fan', 33: 'electric_food_mill_grinder', 34: 'electric_water_boiler', 35: 'faucet', 36: 'fireplace', 37: 'food_blender', 38: 'food_dehydrator', 39: 'food_mixer', 40: 'food_processor', 41: 'fountain', 42: 'freestanding_shelter', 43: 'furniture_cart', 44: 'guitars', 45: 'home', 46: 'home_mirror', 47: 'humidifier', 48: 'ice_cream_maker', 49: 'ice_maker', 50: 'juicer', 51: 'keyboards', 52: 'kick_scooter', 53: 'lap_desk', 54: 'laundry_appliance', 55: 'laundry_hamper', 56: 'light_fixture', 57: 'microphone', 58: 'monitor', 59: 'noise_machine', 60: 'outbuilding', 61: 'personal_computer', 62: 'portable_tool_box', 63: 'pressure_cooker', 64: 'refrigeration_appliance', 65: 'refrigerator', 66: 'rice_cookers', 67: 'robotic_vacuum_cleaner', 68: 'rug', 69: 'sandbox', 70: 'saute_fry_pan', 71: 'scanner', 72: 'shelf', 73: 'shoes', 74: 'slow_cooker', 75: 'sofa', 76: 'speakers', 77: 'sport_table_game', 78: 'stool_seating', 79: 'storage_box', 80: 'storage_hook', 81: 'storage_rack', 82: 'stringed_instruments', 83: 'suitcase', 84: 'sunglasses', 85: 'table', 86: 'tent', 87: 'therapeutic_thermal_compress', 88: 'thermos', 89: 'toaster', 90: 'toilet', 91: 'trash_can', 92: 'turntable', 93: 'utility_cart_wagon', 94: 'video_game_controller', 95: 'wall_art', 96: 'workbench'}

# %% [markdown]
# # label file creation

# %%
# Load and preprocess the training dataset
label_mapping = {}

for i, category_folder in enumerate(os.listdir(dataset_dir)):
    category_path = os.path.join(dataset_dir, category_folder)
    if not os.path.isdir(category_path):  # Skip non-directory files
        continue
    if category_folder == '.ipynb_checkpoints':  # Skip any system-generated folders
        continue
    if category_folder.endswith('.json'):  # Skip JSON files
        continue

    label_mapping[i] = category_folder

# Generate and save the labels file
labels = [label_mapping[i] for i in range(len(label_mapping))]
labels_file = 'labels.txt'

with open(labels_file, 'w') as file:
    file.write('\n'.join(labels))

# %% [markdown]
# # Predition code

# %%
# Take input image from the user
input_image_path = input("Enter the path to the input image: ")
#_____

# model path
model_path = r"C:\Users\ASUS\Desktop\img_class_diksha\keras_model.h5"

labels_path = r"C:\Users\ASUS\Desktop\img_class_diksha\labels.txt"

des_path = f"D:/06-05-23/img_class_pranav/des/"

# Load the pre-trained ResNet50 model
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

# Define functions to preprocess images and extract features
def preprocess_image(image):
    image = image.resize((224, 224))
    image = ImageOps.fit(image, (224, 224))
    image = image.convert("RGB")
    image = np.array(image)
    image = preprocess_input(image)
    return image

def extract_features(image):
    image = preprocess_image(image)
    image = np.expand_dims(image, axis=0)
    features = model.predict(image)
    features = np.reshape(features, (features.shape[0], -1))
    return features

# Define the main function to perform similarity matching
def find_similarity(input_image_path, folder_path):
    # Load the input image
    input_image = Image.open(input_image_path)

    # Extract features from the input image
    input_features = extract_features(input_image)

    folder_features = []
    image_paths = []

    # Loop through the images in the folder
    for root, dirs, files in os.walk(folder_path):
        for file_name in files:
            file_path = os.path.join(root, file_name)

            # Exclude non-image files and JSON files
            if not (file_name.lower().endswith('.jpg') or file_name.lower().endswith('.jpeg') or file_name.lower().endswith('.png')):
                continue

            # Load and preprocess each image in the folder
            image = Image.open(file_path)
            features = extract_features(image)

            # Store the features and image paths for later use
            folder_features.append(features)
            image_paths.append(file_path)

    # Convert the lists to numpy arrays
    folder_features = np.concatenate(folder_features)
    image_paths = np.array(image_paths)

    # Compute cosine similarity scores
    similarity_scores = cosine_similarity(input_features, folder_features)

    # Find the indices of the top 20 most similar images
    top_indices = np.argsort(similarity_scores.ravel())[::-1][:20]

    # Get the paths of the top 20 most similar images
    top_image_paths = image_paths[top_indices]
    top_similarity_scores = similarity_scores[0, top_indices]

    return top_image_paths, top_similarity_scores

# Load the model

model = load_model(model_path, compile=False)

# Load the labels

class_names = open(labels_path, "r").readlines()

# Create the array of the right shape to feed into the keras model
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)



# Load the input image
image = Image.open(input_image_path).convert("RGB")

# Resize and normalize the image
size = (224, 224)
image = ImageOps.fit(image, size)
image_array = np.asarray(image)
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1
data[0] = normalized_image_array

# Predict the category of the input image
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]

# Print the predicted category
print("Predicted Category:", class_name[2:])
if(input ("do you wanna add the image in predicted category folder ? (y/n)")=="y"):
  shutil.copy(input_image_path,folder_path)
elif(input("do you want to make new category manually for this image ? (y/n)")=="y"):
  new_category = input("give the name for new category : ")
  # Create the new folder in the destination directory
  new_folder_path = os.path.join(destination_directory, new_category)
  os.makedirs(new_folder_path, exist_ok=True)
  shutil.copy(input_image_path,new_folder_path)
  sys.exit("your new folder has been appended")



# Select the folder based on the predicted category
folder_path =  des_path + class_name[3:-1]+"/"

# Perform similarity matching
top_image_paths, top_similarity_scores = find_similarity(input_image_path, folder_path)

# Load the input image
input_image = Image.open(input_image_path)

# Plot the input image and the top 20 similar images
fig, axes = plt.subplots(5, 4, figsize=(12, 15))
axes = axes.ravel()

for i, (image_path, similarity_score) in enumerate(zip(top_image_paths, top_similarity_scores)):
    image = Image.open(image_path)
    axes[i].imshow(image)
    axes[i].set_title(f"Similarity Score: {similarity_score:.4f}")
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# #check the paths and directories | if any error occured like "ValueError: need at least one array to concatenate " then check for the paths in prediction code there might be some string slicing mistake.

# %%
des_path = f"D:/06-05-23/img_class_pranav/des/"
folder_path = des_path + class_name[3:-1]+"/"
folder_path

# %%
print("Predicted Category:", class_name[2:])

# %%
print("Predicted Category:", class_name[3:])
if(input ("do you wanna add the image in predicted category folder ? (y/n)")=="y"):
  shutil.copy(input_image_path,folder_path)
